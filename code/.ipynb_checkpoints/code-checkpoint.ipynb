# %%
import warnings
warnings.filterwarnings("ignore")
import itertools
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
from datetime import datetime

# %matplotlib inline

# %%
df = pd.read_csv('../data/sales-of-company-x-jan-1965-to-m.csv')
df.head()
# Out:
#      Month Sales of company X, Jan. 1965 to May 1971
# 0  1965-01                                       154
# 1  1965-02                                        96
# 2  1965-03                                        73
# 3  1965-04                                        49
# 4  1965-05                                        36

# %%
df = df.rename(columns={'Month':'month', 'Sales of company X, Jan. 1965 to May 1971':'sales'})
df.head(2)
# Out:
#      month sales
# 0  1965-01   154
# 1  1965-02    96

# %%
df['month'].tail()
# Out:
# 73               1971-02
# 74               1971-03
# 75               1971-04
# 76               1971-05
# 77    Sales of company X
# Name: month, dtype: object

# %%
df.drop(index=77, inplace=True)

# %%
df['month'].min(), df['month'].max()
# Out:
# ('1965-01', '1971-05')

# %%
df.isnull().sum()
# Out:
# month    0
# sales    0
# dtype: int64

# %%
df.sales = df.sales.astype('int64')

# %%
df = df.groupby('month')['sales'].sum().reset_index()

# %%
df['month'] = pd.to_datetime(df.month, format = '%Y-%m-%d')

# %%
df = df.set_index('month')
df.index
# Out:
# DatetimeIndex(['1965-01-01', '1965-02-01', '1965-03-01', '1965-04-01',
#                '1965-05-01', '1965-06-01', '1965-07-01', '1965-08-01',
#                '1965-09-01', '1965-10-01', '1965-11-01', '1965-12-01',
#                '1966-01-01', '1966-02-01', '1966-03-01', '1966-04-01',
#                '1966-05-01', '1966-06-01', '1966-07-01', '1966-08-01',
#                '1966-09-01', '1966-10-01', '1966-11-01', '1966-12-01',
#                '1967-01-01', '1967-02-01', '1967-03-01', '1967-04-01',
#                '1967-05-01', '1967-06-01', '1967-07-01', '1967-08-01',
#                '1967-09-01', '1967-10-01', '1967-11-01', '1967-12-01',
#                '1968-01-01', '1968-02-01', '1968-03-01', '1968-04-01',
#                '1968-05-01', '1968-06-01', '1968-07-01', '1968-08-01',
#                '1968-09-01', '1968-10-01', '1968-11-01', '1968-12-01',
#                '1969-01-01', '1969-02-01', '1969-03-01', '1969-04-01',
# ...

# %%
df.head()
# Out:
#             sales
# month
# 1965-01-01    154
# 1965-02-01     96
# 1965-03-01     73
# 1965-04-01     49
# 1965-05-01     36

# %%
y = df['sales']

# %%
y.plot(figsize=(15, 6))
plt.show()

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
                continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1112.5130723397733
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:895.8566138988509
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:759.7969978318756
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:616.0311132892906
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:725.9045082910741
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:710.2803007829078
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:618.8242209701367
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:603.6043290693696
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1027.578809661662
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:834.3938275586061
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:730.9967273898612
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:598.083212738621
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:723.3175002012642
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:693.1577120786085
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:616.4078920024338
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:590.9524155653115
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:907.2762033799626
# ...

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7369      0.215     -3.426      0.001      -1.158      -0.315
# ma.L1          0.2985      0.271      1.101      0.271      -0.233       0.830
# ar.S.L12      -0.0348      0.176     -0.197      0.844      -0.381       0.311
# sigma2      3845.0646    793.580      4.845      0.000    2289.675    5400.454
# ...

# %% [markdown]
# ## We need to be certain that our residuals are uncorrelated and normally distributed with zero mean.
#
# - In the histogram, we see that the red KDE line follows fairly closely with the N(0,1) line. This is a good indication that the residuals are normally distributed to an extent.
#
# - The qq-plot shows that the ordered distribution of residuals follows the linear trend.
#
# - The standardized residual plot does not display any obvious seasonality and appears to be white noise. This is confirmed by the correlogram plot, which shows that the time series residuals have low correlation with lagged versions of itself.

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %% [markdown]
# ## We set the forecasts to start at Jan 1st of 1970. We set (dynamic=  False) to ensure that at every point, we take into account the full history of information up to that particular point.

# %%
pred = results.get_prediction(start=pd.to_datetime('1970-01-01'), dynamic=False)
pred_ci = pred.conf_int()

ax = y['1967':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Date')
ax.set_ylabel('Company Sales')
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['1970-01-01':]
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 7416.36

# %% [markdown]
# ## I like to look at the RMSE to see how far we are off on average per residual

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 86.12

# %% [markdown]
# ## This is to show our forecast. We are looking at 250 months into the future with a confidence interval that grows as we go further into the future

# %%
pred_uc = results.get_forecast(steps=250)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Company Sales')
plt.legend()
plt.show()

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#        month  sales
# 0 1965-01-01    154
# 1 1965-02-01     96
# 2 1965-03-01     73
# 3 1965-04-01     49
# 4 1965-05-01     36

# %% [markdown]
# ## I wanted to look into using Prophet. FBProphet is great at picking up non-linear yearly, weekly, and daily seasonality and holiday trends.

# %%
from fbprophet import Prophet
df = df.rename(columns={'month': 'ds', 'sales': 'y'})

# %%
model = Prophet(interval_width=0.95)
model.fit(df)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
df.shape
# Out:
# (77, 2)

# %% [markdown]
# ## We want to take a look at the where the sales are headed. With Prophet's make_future_dataframe, we can plot the dataframe to see a forecast:
# - The black dots are the data points
# - The dark blue line is the prediction after 1971
# - The light blue is the uncertainty intervals (floor and ceiling)

# %%
forecast = model.make_future_dataframe(periods=60, freq='MS')
forecast = model.predict(forecast)
plt.figure(figsize=(18, 6))
model.plot(forecast, xlabel = 'Date', ylabel = 'Sales')
plt.title('Company Sales');

# %%
forecast.head()
# Out:
#           ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1965-01-01  115.939439   69.541243  316.525165   115.939439   115.939439
# 1 1965-02-01  120.411880  -60.690369  174.143213   120.411880   120.411880
# 2 1965-03-01  124.451504 -104.691268  140.838000   124.451504   124.451504
# 3 1965-04-01  128.923946 -138.652757   96.947558   128.923946   128.923946
# 4 1965-05-01  133.252114 -143.784066  100.288213   133.252114   133.252114
#
#    additive_terms  additive_terms_lower  additive_terms_upper      yearly  \
# 0       84.585078             84.585078             84.585078   84.585078
# 1      -62.756483            -62.756483            -62.756483  -62.756483
# 2     -108.899294           -108.899294           -108.899294 -108.899294
# 3     -151.488605           -151.488605           -151.488605 -151.488605
# 4     -158.177778           -158.177778           -158.177778 -158.177778
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# ...

# %%
plt.figure(figsize=(10, 7))
plt.plot(forecast['ds'], forecast['trend'], 'b-')
plt.legend(); plt.xlabel('Date'); plt.ylabel('Sales')
plt.title('Company Trend Predictions');

# %%
plt.figure(figsize=(10, 7))
plt.plot(forecast['ds'], forecast['yhat'], 'b-')
plt.legend(); plt.xlabel('Date'); plt.ylabel('Sales')
plt.title('Sales Predictions');

# %%
model.plot_components(forecast);
